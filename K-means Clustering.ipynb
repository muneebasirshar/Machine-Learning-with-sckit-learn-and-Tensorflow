# %% [markdown]
# clustering is typically an unsupervised learning. Labels are generally not known at the begining.
# The following steps are followed:
# 1. select random points as centriods.
# 2. find the distance of each point from each of these centriods
# 3. assign each point to the cluster centriod whose distance is minimum to its position.
# 4. after all the points have been assigned to a centriod find mean for each cluster
# 5. the cluster mean is the new centriod.
# Repeat the steps 2-5 untill convergence

# %% [markdown]
# The quality of a cluster depands on the variance captured by the cluster

# %%
#imports 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn import linear_model
# %matplotlib notebook
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
import seaborn as sns

# %%
import random
random.seed(0)
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn import preprocessing
from mpl_toolkits.mplot3d import Axes3D

# %%
DataFile = pd.read_csv('C:/Users/muneeba/Desktop/THESIS/DataDistributionPCA.csv') 
DataFile=DataFile[:65]
DataFile=DataFile.iloc[:,4:10]
DataFile.describe()
data_frame = pd.DataFrame( DataFile)

# %%
kmeans_model = KMeans(3, random_state=1)
y_pred = kmeans_model.fit_predict(data_frame)
variance_explained = kmeans_model.score(data_frame)

# %%
variance_explained
# Out:
# -0.27928674010781251

# %%
kmeans_model = KMeans(2, random_state=1)
y_pred = kmeans_model.fit_predict(data_frame)
variance_explained = kmeans_model.score(data_frame)

# %%
variance_explained
# Out:
# -0.58808220872758654

# %%
kmeans_model = KMeans(64, random_state=1)
y_pred = kmeans_model.fit_predict(data_frame)
variance_explained = kmeans_model.score(data_frame)

# %%
variance_explained
# Out:
# -2.3089490809675868e-16

# %%
kmeans_model = KMeans(6, random_state=1)
y_pred = kmeans_model.fit_predict(data_frame)
variance_explained = kmeans_model.score(data_frame)
variance_explained
# Out:
# -0.077482287710498615

# %%
kmeans_model = KMeans(15, random_state=1)
y_pred = kmeans_model.fit_predict(data_frame)
variance_explained = kmeans_model.score(data_frame)
variance_explained
# Out:
# -0.0086622677972058738

# %%
def elbow_method():
    explained_variances = []
    Ks = list(range(3, 30))
    for K in Ks:
        kmeans_model = KMeans(K, random_state=1)
        y_pred = kmeans_model.fit_predict(data_frame)
        explained_variance  = kmeans_model.score(data_frame) 
        explained_variances.append(explained_variance)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(Ks, np.exp(explained_variances), marker='o')
    plt.xlabel('number of clusters')
    plt.ylabel('variance captures')
    plt.title('optimal number of cluster members')
    plt.show()
    
elbow_method()
# Out:
# <img src="data:image/png;base64,..." width="640">
